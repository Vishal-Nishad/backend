# %% [markdown]
# Below is your **ultimate OOP + Backend Design cheat sheet**—optimized for **interviews + real production thinking**.
# No fluff. Only what gives you **signal in interviews**.
#
# ---
#
# # 🔥 1. Core OOP Mental Model (VERY IMPORTANT)
#
# 👉 Don’t think “4 pillars”
# 👉 Think:
#
# ```plaintext
# Structure → Behavior → Collaboration → Flexibility
# ```
#
# ---
#
# # 🔥 2. When to use Class vs Function
#
# ## Use CLASS when:
#
# * state + behavior together
# * dependencies (DB, cache, API)
# * need extensibility
#
# ## Use FUNCTION when:
#
# * stateless logic
# * utility/helper
#
# 👉 Interview line:
#
# > I avoid unnecessary classes and prefer functions for simple stateless logic.
#
# ---
#
# # 🔥 3. Core Concepts (Ultra Crisp)
#
# ---
#
# ## ✅ Encapsulation
#
# 👉 Hide internal logic
#
# ```python
# class UserService:
#     def __init__(self, repo):
#         self._repo = repo
# ```
#
# ✔ Used in:
#
# * service layer
# * business logic isolation
#
# ---
#
# ## ✅ Abstraction
#
# 👉 Define contract (WHAT)
#
# ```python
# class PaymentGateway(ABC):
#     def charge(self): pass
# ```
#
# ✔ Used in:
#
# * payment systems
# * cache layers
# * integrations
#
# ---
#
# ## ✅ Inheritance
#
# 👉 “is-a” relationship
#
# ✔ Used for:
#
# * base repository
# * shared interface
# * exception hierarchy
#
# ❌ Avoid deep chains
#
# ---
#
# ## ✅ Composition (MOST IMPORTANT)
#
# 👉 “has-a” relationship
#
# ```python
# class Service:
#     def __init__(self, repo):
#         self.repo = repo
# ```
#
# ✔ Used everywhere in backend
#
# ---
#
# ## ✅ Polymorphism
#
# 👉 same interface, different behavior
#
# ```python
# gateway.charge()
# ```
#
# ✔ Used in:
#
# * pluggable systems
#
# ---
#
# # 🔥 4. Composition vs Inheritance (INTERVIEW GOLD)
#
# | Use case            | Use         |
# | ------------------- | ----------- |
# | “is-a” relationship | Inheritance |
# | dependency usage    | Composition |
#
# 👉 Golden line:
#
# > Prefer composition over inheritance for flexibility and loose coupling.
#
# ---
#
# # 🔥 5. Dependency Injection (CRITICAL)
#
# 👉 Don’t do:
#
# ```python
# self.repo = UserRepository() ❌
# ```
#
# 👉 Do:
#
# ```python
# def __init__(self, repo):
#     self.repo = repo ✔
# ```
#
# ✔ Benefits:
#
# * testability
# * flexibility
# * loose coupling
#
# ---
#
# # 🔥 6. Testability (VERY IMPORTANT)
#
# 👉 With DI:
#
# ```python
# service = UserService(FakeRepo())
# ```
#
# ✔ No DB
# ✔ Fast tests
#
# 👉 Interview line:
#
# > DI enables mocking dependencies, making unit tests fast and reliable.
#
# ---
#
# # 🔥 7. Duck Typing (Python Advantage)
#
# 👉 No strict interface needed
#
# ```python
# obj.charge()
# ```
#
# ✔ Used in:
#
# * testing
# * flexible design
#
# ---
#
# # 🔥 8. Shared Mutable State (CRITICAL BUG AREA)
#
# ❌ Avoid:
#
# ```python
# class A:
#     items = []
# ```
#
# 👉 Causes:
#
# * race conditions
# * data leaks
#
# ✔ Rule:
#
# ```plaintext
# Keep services stateless
# ```
#
# ---
#
# # 🔥 9. Instance vs Class Attributes
#
# | Type     | Use              |
# | -------- | ---------------- |
# | Instance | per object data  |
# | Class    | constants/config |
#
# ❌ Never:
#
# ```python
# class A:
#     data = []  # shared bug
# ```
#
# ---
#
# # 🔥 10. Methods Cheat Sheet
#
# | Type         | Use         |
# | ------------ | ----------- |
# | Instance     | most common |
# | Classmethod  | factory     |
# | Staticmethod | rare        |
#
# ---
#
# # 🔥 11. `super()` Usage
#
# 👉 Always use in inheritance:
#
# ```python
# super().__init__()
# ```
#
# ✔ Ensures parent initialization
#
# ---
#
# # 🔥 12. Access Modifiers (Python Reality)
#
# | Type       | Meaning       |
# | ---------- | ------------- |
# | public     | default       |
# | _protected | internal      |
# | __private  | name mangling |
#
# 👉 Python uses **convention, not enforcement**
#
# ---
#
# # 🔥 13. Getters/Setters (Python Way)
#
# 👉 Use `@property`
#
# ✔ For:
#
# * validation
# * computed values
#
# ---
#
# # 🔥 14. Backend Architecture Pattern
#
# ```plaintext
# Controller → Service → Repository → DB
#                     → Cache
#                     → External APIs
# ```
#
# ---
#
# ## Where OOP fits:
#
# | Layer        | Concept          |
# | ------------ | ---------------- |
# | Service      | composition + DI |
# | Repository   | abstraction      |
# | External API | polymorphism     |
#
# ---
#
# # 🔥 15. Real Production Patterns
#
# ---
#
# ## ✅ Pattern 1: Service + Repo + Cache
#
# ```python
# class Service:
#     def __init__(self, repo, cache):
#         self.repo = repo
#         self.cache = cache
# ```
#
# ---
#
# ## ✅ Pattern 2: Strategy Pattern (VERY COMMON)
#
# ```python
# PaymentGateway → Stripe / Razorpay
# ```
#
# ---
#
# ## ✅ Pattern 3: Adapter Pattern
#
# Wrap external APIs into clean interface
#
# ---
#
# # 🔥 16. What Interviewers ACTUALLY Check
#
# ---
#
# ## They don’t care about:
#
# ❌ textbook definitions
# ❌ deep theory
#
# ---
#
# ## They care about:
#
# ✔ Can you design clean system?
# ✔ Can you avoid tight coupling?
# ✔ Can you write testable code?
# ✔ Do you understand real tradeoffs?
#
# ---
#
# # 🔥 17. Most Asked Interview Questions
#
# ---
#
# ## Q1. Composition vs Inheritance?
#
# 👉 Answer:
#
# * composition for flexibility
# * inheritance for structure
#
# ---
#
# ## Q2. What is DI?
#
# 👉 Passing dependencies → improves testability
#
# ---
#
# ## Q3. What is abstraction?
#
# 👉 interface defining behavior
#
# ---
#
# ## Q4. What is polymorphism?
#
# 👉 same interface, different implementations
#
# ---
#
# ## Q5. How do you design testable code?
#
# 👉 DI + loose coupling + no global state
#
# ---
#
# ## Q6. What is shared mutable state?
#
# 👉 shared + modifiable = bugs
#
# ---
#
# # 🔥 18. Golden Rules (MEMORIZE THESE)
#
# ---
#
# ## Rule 1
#
# 👉 Prefer composition over inheritance
#
# ---
#
# ## Rule 2
#
# 👉 Use dependency injection
#
# ---
#
# ## Rule 3
#
# 👉 Keep services stateless
#
# ---
#
# ## Rule 4
#
# 👉 Depend on abstraction, not implementation
#
# ---
#
# ## Rule 5
#
# 👉 Avoid shared mutable state
#
# ---
#
# ## Rule 6
#
# 👉 Write code that is easy to test
#
# ---
#
# # 🔥 19. 60-sec Perfect Interview Answer (OOP)
#
# > In Python backend systems, I use OOP mainly for structuring services, repositories, and integrations. I prefer composition over inheritance to keep components loosely coupled and flexible. I use dependency injection to pass dependencies like database or cache clients, which improves testability. Abstraction is used to define interfaces for components like payment gateways or caches, enabling multiple implementations. I also ensure services remain stateless to avoid shared mutable state issues. Overall, I focus on clean design, maintainability, and testability rather than textbook OOP.
#
# ---
#
# # 🔥 20. Final Mindset (THIS MAKES YOU STRONG)
#
# 👉 Don’t think:
#
# ```plaintext
# "OOP concepts"
# ```
#
# 👉 Think:
#
# ```plaintext
# How to build clean, scalable backend systems
# ```
#
# ---
#
# If you want next (highly recommended before interviews):
#
# 👉 I can take a **full mock interview (Python backend + OOP + system design)**
# 👉 or give **top 20 coding + design questions with expected answers**

# %% [markdown]
# Below is your **ultimate OOP + Backend Design cheat sheet**—optimized for **interviews + real production thinking**.
# No fluff. Only what gives you **signal in interviews**.
#
# ---
#
# # 🔥 1. Core OOP Mental Model (VERY IMPORTANT)
#
# 👉 Don’t think “4 pillars”
# 👉 Think:
#
# ```plaintext
# Structure → Behavior → Collaboration → Flexibility
# ```
#
# ---
#
# # 🔥 2. When to use Class vs Function
#
# ## Use CLASS when:
#
# * state + behavior together
# * dependencies (DB, cache, API)
# * need extensibility
#
# ## Use FUNCTION when:
#
# * stateless logic
# * utility/helper
#
# 👉 Interview line:
#
# > I avoid unnecessary classes and prefer functions for simple stateless logic.
#
# ---
#
# # 🔥 3. Core Concepts (Ultra Crisp)
#
# ---
#
# ## ✅ Encapsulation
#
# 👉 Hide internal logic
#
# ```python
# class UserService:
#     def __init__(self, repo):
#         self._repo = repo
# ```
#
# ✔ Used in:
#
# * service layer
# * business logic isolation
#
# ---
#
# ## ✅ Abstraction
#
# 👉 Define contract (WHAT)
#
# ```python
# class PaymentGateway(ABC):
#     def charge(self): pass
# ```
#
# ✔ Used in:
#
# * payment systems
# * cache layers
# * integrations
#
# ---
#
# ## ✅ Inheritance
#
# 👉 “is-a” relationship
#
# ✔ Used for:
#
# * base repository
# * shared interface
# * exception hierarchy
#
# ❌ Avoid deep chains
#
# ---
#
# ## ✅ Composition (MOST IMPORTANT)
#
# 👉 “has-a” relationship
#
# ```python
# class Service:
#     def __init__(self, repo):
#         self.repo = repo
# ```
#
# ✔ Used everywhere in backend
#
# ---
#
# ## ✅ Polymorphism
#
# 👉 same interface, different behavior
#
# ```python
# gateway.charge()
# ```
#
# ✔ Used in:
#
# * pluggable systems
#
# ---
#
# # 🔥 4. Composition vs Inheritance (INTERVIEW GOLD)
#
# | Use case            | Use         |
# | ------------------- | ----------- |
# | “is-a” relationship | Inheritance |
# | dependency usage    | Composition |
#
# 👉 Golden line:
#
# > Prefer composition over inheritance for flexibility and loose coupling.
#
# ---
#
# # 🔥 5. Dependency Injection (CRITICAL)
#
# 👉 Don’t do:
#
# ```python
# self.repo = UserRepository() ❌
# ```
#
# 👉 Do:
#
# ```python
# def __init__(self, repo):
#     self.repo = repo ✔
# ```
#
# ✔ Benefits:
#
# * testability
# * flexibility
# * loose coupling
#
# ---
#
# # 🔥 6. Testability (VERY IMPORTANT)
#
# 👉 With DI:
#
# ```python
# service = UserService(FakeRepo())
# ```
#
# ✔ No DB
# ✔ Fast tests
#
# 👉 Interview line:
#
# > DI enables mocking dependencies, making unit tests fast and reliable.
#
# ---
#
# # 🔥 7. Duck Typing (Python Advantage)
#
# 👉 No strict interface needed
#
# ```python
# obj.charge()
# ```
#
# ✔ Used in:
#
# * testing
# * flexible design
#
# ---
#
# # 🔥 8. Shared Mutable State (CRITICAL BUG AREA)
#
# ❌ Avoid:
#
# ```python
# class A:
#     items = []
# ```
#
# 👉 Causes:
#
# * race conditions
# * data leaks
#
# ✔ Rule:
#
# ```plaintext
# Keep services stateless
# ```
#
# ---
#
# # 🔥 9. Instance vs Class Attributes
#
# | Type     | Use              |
# | -------- | ---------------- |
# | Instance | per object data  |
# | Class    | constants/config |
#
# ❌ Never:
#
# ```python
# class A:
#     data = []  # shared bug
# ```
#
# ---
#
# # 🔥 10. Methods Cheat Sheet
#
# | Type         | Use         |
# | ------------ | ----------- |
# | Instance     | most common |
# | Classmethod  | factory     |
# | Staticmethod | rare        |
#
# ---
#
# # 🔥 11. `super()` Usage
#
# 👉 Always use in inheritance:
#
# ```python
# super().__init__()
# ```
#
# ✔ Ensures parent initialization
#
# ---
#
# # 🔥 12. Access Modifiers (Python Reality)
#
# | Type       | Meaning       |
# | ---------- | ------------- |
# | public     | default       |
# | _protected | internal      |
# | __private  | name mangling |
#
# 👉 Python uses **convention, not enforcement**
#
# ---
#
# # 🔥 13. Getters/Setters (Python Way)
#
# 👉 Use `@property`
#
# ✔ For:
#
# * validation
# * computed values
#
# ---
#
# # 🔥 14. Backend Architecture Pattern
#
# ```plaintext
# Controller → Service → Repository → DB
#                     → Cache
#                     → External APIs
# ```
#
# ---
#
# ## Where OOP fits:
#
# | Layer        | Concept          |
# | ------------ | ---------------- |
# | Service      | composition + DI |
# | Repository   | abstraction      |
# | External API | polymorphism     |
#
# ---
#
# # 🔥 15. Real Production Patterns
#
# ---
#
# ## ✅ Pattern 1: Service + Repo + Cache
#
# ```python
# class Service:
#     def __init__(self, repo, cache):
#         self.repo = repo
#         self.cache = cache
# ```
#
# ---
#
# ## ✅ Pattern 2: Strategy Pattern (VERY COMMON)
#
# ```python
# PaymentGateway → Stripe / Razorpay
# ```
#
# ---
#
# ## ✅ Pattern 3: Adapter Pattern
#
# Wrap external APIs into clean interface
#
# ---
#
# # 🔥 16. What Interviewers ACTUALLY Check
#
# ---
#
# ## They don’t care about:
#
# ❌ textbook definitions
# ❌ deep theory
#
# ---
#
# ## They care about:
#
# ✔ Can you design clean system?
# ✔ Can you avoid tight coupling?
# ✔ Can you write testable code?
# ✔ Do you understand real tradeoffs?
#
# ---
#
# # 🔥 17. Most Asked Interview Questions
#
# ---
#
# ## Q1. Composition vs Inheritance?
#
# 👉 Answer:
#
# * composition for flexibility
# * inheritance for structure
#
# ---
#
# ## Q2. What is DI?
#
# 👉 Passing dependencies → improves testability
#
# ---
#
# ## Q3. What is abstraction?
#
# 👉 interface defining behavior
#
# ---
#
# ## Q4. What is polymorphism?
#
# 👉 same interface, different implementations
#
# ---
#
# ## Q5. How do you design testable code?
#
# 👉 DI + loose coupling + no global state
#
# ---
#
# ## Q6. What is shared mutable state?
#
# 👉 shared + modifiable = bugs
#
# ---
#
# # 🔥 18. Golden Rules (MEMORIZE THESE)
#
# ---
#
# ## Rule 1
#
# 👉 Prefer composition over inheritance
#
# ---
#
# ## Rule 2
#
# 👉 Use dependency injection
#
# ---
#
# ## Rule 3
#
# 👉 Keep services stateless
#
# ---
#
# ## Rule 4
#
# 👉 Depend on abstraction, not implementation
#
# ---
#
# ## Rule 5
#
# 👉 Avoid shared mutable state
#
# ---
#
# ## Rule 6
#
# 👉 Write code that is easy to test
#
# ---
#
# # 🔥 19. 60-sec Perfect Interview Answer (OOP)
#
# > In Python backend systems, I use OOP mainly for structuring services, repositories, and integrations. I prefer composition over inheritance to keep components loosely coupled and flexible. I use dependency injection to pass dependencies like database or cache clients, which improves testability. Abstraction is used to define interfaces for components like payment gateways or caches, enabling multiple implementations. I also ensure services remain stateless to avoid shared mutable state issues. Overall, I focus on clean design, maintainability, and testability rather than textbook OOP.
#
# ---
#
# # 🔥 20. Final Mindset (THIS MAKES YOU STRONG)
#
# 👉 Don’t think:
#
# ```plaintext
# "OOP concepts"
# ```
#
# 👉 Think:
#
# ```plaintext
# How to build clean, scalable backend systems
# ```
#
# ---
#
# If you want next (highly recommended before interviews):
#
# 👉 I can take a **full mock interview (Python backend + OOP + system design)**
# 👉 or give **top 20 coding + design questions with expected answers**

# %% [markdown]
# Perfect—this is **exactly how interviewers test real understanding**.
#
# Below are **10 realistic backend scenarios**.
# For each, I’ll show:
#
# * ✅ Correct choice (Class / Function)
# * ❌ Wrong approach
# * 💡 Why (production reasoning)
# * 🎯 How to answer in interview
#
# ---
#
# # 🔥 Scenario 1 — Format API response
#
# ## Problem
#
# Convert DB user → API response
#
# ---
#
# ## ✅ Use FUNCTION
#
# ```python
# def format_user(user):
#     return {
#         "id": user["id"],
#         "name": user["name"]
#     }
# ```
#
# ---
#
# ## 💡 Why
#
# * stateless
# * simple transformation
# * no dependency
#
# ---
#
# ## ❌ Wrong (class)
#
# ```python
# class Formatter:
#     def format(self, user):
#         ...
# ```
#
# ---
#
# ## 🎯 Interview line
#
# > Since this is a pure transformation with no state, I prefer a function.
#
# ---
#
# # 🔥 Scenario 2 — Fetch user from DB + cache
#
# ---
#
# ## ✅ Use CLASS
#
# ```python
# class UserService:
#     def __init__(self, repo, cache):
#         self.repo = repo
#         self.cache = cache
# ```
#
# ---
#
# ## 💡 Why
#
# * uses dependencies
# * business logic
# * multi-step workflow
#
# ---
#
# ## ❌ Wrong (function)
#
# ```python
# def get_user(user_id):
#     repo = UserRepository()
# ```
#
# ---
#
# ## 🎯 Interview line
#
# > This involves dependencies and business logic, so I use a class with dependency injection.
#
# ---
#
# # 🔥 Scenario 3 — Validate email
#
# ---
#
# ## ✅ Use FUNCTION
#
# ```python
# def is_valid_email(email):
#     return "@" in email
# ```
#
# ---
#
# ## 💡 Why
#
# * stateless
# * reusable utility
#
# ---
#
# ## 🎯 Interview line
#
# > This is a simple utility, so function is enough.
#
# ---
#
# # 🔥 Scenario 4 — Payment processing (multiple gateways)
#
# ---
#
# ## ✅ Use CLASS
#
# ```python
# class PaymentService:
#     def __init__(self, gateway):
#         self.gateway = gateway
# ```
#
# ---
#
# ## 💡 Why
#
# * extensibility
# * polymorphism
# * external dependency
#
# ---
#
# ## ❌ Wrong
#
# ```python
# def pay(amount, type):
#     if type == "stripe":
# ```
#
# ---
#
# ## 🎯 Interview line
#
# > Since multiple implementations are expected, I use classes with abstraction.
#
# ---
#
# # 🔥 Scenario 5 — Calculate tax
#
# ---
#
# ## ✅ Use FUNCTION
#
# ```python
# def calculate_tax(amount):
#     return amount * 0.18
# ```
#
# ---
#
# ## 💡 Why
#
# * pure logic
# * no state
#
# ---
#
# ## 🎯 Interview line
#
# > This is a pure calculation, so function keeps it simple.
#
# ---
#
# # 🔥 Scenario 6 — API client (external service)
#
# ---
#
# ## ✅ Use CLASS
#
# ```python
# class PaymentClient:
#     def __init__(self, base_url):
#         self.base_url = base_url
#
#     def create_payment(self):
#         ...
# ```
#
# ---
#
# ## 💡 Why
#
# * config/state (base_url)
# * multiple methods
# * reuse
#
# ---
#
# ## 🎯 Interview line
#
# > External integrations usually need configuration and multiple operations, so I use a class.
#
# ---
#
# # 🔥 Scenario 7 — Logging helper
#
# ---
#
# ## ✅ Use FUNCTION (simple case)
#
# ```python
# def log_error(msg):
#     print(msg)
# ```
#
# ---
#
# ## OR CLASS (complex logging system)
#
# ```python
# class Logger:
#     def __init__(self, sink):
#         self.sink = sink
# ```
#
# ---
#
# ## 💡 Rule
#
# | Complexity                  | Use      |
# | --------------------------- | -------- |
# | simple                      | function |
# | complex (multiple backends) | class    |
#
# ---
#
# ## 🎯 Interview line
#
# > I choose function for simple logging, but class if logging has multiple implementations.
#
# ---
#
# # 🔥 Scenario 8 — Cache system (Redis vs Memory)
#
# ---
#
# ## ✅ Use CLASS
#
# ```python
# class Cache:
#     def get(self, key): pass
# ```
#
# ---
#
# ## 💡 Why
#
# * multiple implementations
# * abstraction needed
#
# ---
#
# ## 🎯 Interview line
#
# > Cache systems require interchangeable implementations, so class-based abstraction is ideal.
#
# ---
#
# # 🔥 Scenario 9 — Password hashing
#
# ---
#
# ## ✅ Use FUNCTION
#
# ```python
# def hash_password(password):
#     return hashlib.sha256(password.encode()).hexdigest()
# ```
#
# ---
#
# ## 💡 Why
#
# * stateless
# * utility
#
# ---
#
# ## 🎯 Interview line
#
# > This is a stateless helper, so function is preferred.
#
# ---
#
# # 🔥 Scenario 10 — Order processing workflow
#
# ---
#
# ## ✅ Use CLASS
#
# ```python
# class OrderService:
#     def __init__(self, repo, payment):
#         self.repo = repo
#         self.payment = payment
#
#     def place_order(self):
#         ...
# ```
#
# ---
#
# ## 💡 Why
#
# * multiple steps
# * dependencies
# * business logic
#
# ---
#
# ## 🎯 Interview line
#
# > Complex workflows with dependencies are best modeled using classes.
#
# ---
#
# # 🔥 FINAL DECISION FRAMEWORK (VERY IMPORTANT)
#
# ---
#
# ## Ask these 3 questions:
#
# ---
#
# ### 1. Does it need state or dependencies?
#
# 👉 YES → Class
# 👉 NO → Function
#
# ---
#
# ### 2. Is it simple transformation?
#
# 👉 YES → Function
#
# ---
#
# ### 3. Will it grow or have multiple implementations?
#
# 👉 YES → Class
#
# ---
#
# # 🔥 SUPER SHORT MEMORY
#
# ```plaintext
# Function → simple, stateless
# Class → state, dependency, extensibility
# ```
#
# ---
#
# # 🔥 FINAL INTERVIEW ANSWER (BEST)
#
# > I use functions for stateless operations like transformations, validations, or utilities, and classes when there is state, dependencies, or a need for extensibility, such as services interacting with databases or external APIs. This helps keep the system simple while ensuring flexibility and maintainability.
#
# ---
#
# # 🔥 One line to impress interviewer
#
# > I avoid overengineering by defaulting to functions, and introduce classes only when there’s a clear need for state, dependencies, or extensibility.
#
# ---
#
# If you want next (very powerful):
#
# 👉 I can give you **10 tricky follow-up questions interviewers ask on these scenarios**
# 👉 or a **live mock interview where I challenge your decisions**
